# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "1"

import torch
import pandas as pd
from sklearn.model_selection import train_test_split
from tqdm import tqdm

import pickle

# %% [markdown]
# # Constants

# %%
RANDOM_STATE = 42
TEST_SIZE = 0.2
VAL_SIZE = 0.5
DATASET_CSV = "organs_selected_downsampled.csv"
DATASET_FOLDER = "./dataset_obj/"

# %% [markdown]
# # Load data

# %%
organs = pd.read_csv(DATASET_CSV)
organs.rename(columns={
    "Unnamed: 0": "original_index",
    "Unnamed: 0.1": "new_index"
}, inplace=True)

# %%
available_latents_paths = [os.path.join(DATASET_FOLDER, latent) for latent in os.listdir(DATASET_FOLDER)]

# %%
organs
# Out:
#       new_index  original_index                     Name     Category  \
# 0          1061           45713  s0178_aorta.nii.g_1.stl        aorta
# 1           127            8720   016793_kidneyright.stl  kidneyright
# 2           714           30529         086609_aorta.stl        aorta
# 3          2285           92354  s1016_liver.nii.g_1.stl        liver
# 4          1687           68838  s0611_aorta.nii.g_1.stl        aorta
# ...         ...             ...                      ...          ...
# 2495       2385           96504  s1094_liver.nii.g_1.stl        liver
# 2496       1088           46642  s0196_liver.nii.g_1.stl        liver
# 2497        426           19830   047727_kidneyright.stl  kidneyright
# 2498       2608          105140  s1257_liver.nii.g_1.stl        liver
# 2499        972           42561  s0108_aorta.nii.g_1.stl        aorta
#
#                                                     URL SubCategory  \
# 0     https://uni-duisburg-essen.sciebo.de/s/HeShw1G...       aorta
# 1     https://uni-duisburg-essen.sciebo.de/s/HeShw1G...      kidney
# 2     https://uni-duisburg-essen.sciebo.de/s/HeShw1G...       aorta
# 3     https://uni-duisburg-essen.sciebo.de/s/HeShw1G...       liver
# 4     https://uni-duisburg-essen.sciebo.de/s/HeShw1G...       aorta
# ...                                                 ...         ...
# 2495  https://uni-duisburg-essen.sciebo.de/s/HeShw1G...       liver
# 2496  https://uni-duisburg-essen.sciebo.de/s/HeShw1G...       liver
# 2497  https://uni-duisburg-essen.sciebo.de/s/HeShw1G...      kidney
# 2498  https://uni-duisburg-essen.sciebo.de/s/HeShw1G...       liver
# 2499  https://uni-duisburg-essen.sciebo.de/s/HeShw1G...       aorta
#
#                            id
# 0        0s0178_aorta.nii.g_1
# 1         1016793_kidneyright
# 2               2086609_aorta
# 3        3s1016_liver.nii.g_1
# 4        4s0611_aorta.nii.g_1
# ...                       ...
# 2495  2495s1094_liver.nii.g_1
# 2496  2496s0196_liver.nii.g_1
# 2497   2497047727_kidneyright
# 2498  2498s1257_liver.nii.g_1
# 2499  2499s0108_aorta.nii.g_1
#
# [2500 rows x 7 columns]

# %%
len(organs), len(available_latents_paths)
# Out:
# (2500, 1381)

# %% [markdown]
# # Delete corrupted .pt files (if any)

# %%
for file in tqdm(available_latents_paths):
    try:
        if file.endswith(".pt") and ("ipynb_checkpoints" not in file):
            torch.load(file)
    except:
        print(f"Delete corrupted file: {file}")
        os.remove(file)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1381/1381 [00:03<00:00, 413.48it/s]

# %% [markdown]
# # Train-Val-Test split

# %%
available_latents = [latent.replace(".pt", "") for latent in os.listdir(DATASET_FOLDER)]

# %%
available_latents
# Out:
# ['727_087979_kidneyright',
#  '1634_s0578_liver.nii.g_1',
#  '970_s0107_aorta.nii.g_1',
#  '362_041469_aorta',
#  '1494_s0475_aorta.nii.g_1',
#  '704_085229_liver',
#  '1974_s0791_liver.nii.g_1',
#  '2434_s1131_aorta.nii.g_1',
#  '2573_s1237_liver.nii.g_1',
#  '1161_s0245_liver.nii.g_1',
#  '2516_s1189_liver.nii.g_1',
#  '1789_s0674_liver.nii.g_1',
#  '864_s0031_liver.nii.g_1',
#  '2279_s1012_aorta.nii.g_1',
#  '662_078645_liver',
#  '2262_s0999_liver.nii.g_1',
#  '96_012980_aorta',
#  '1265_s0324_aorta.nii.g_1',
#  '1428_s0429_liver.nii.g_1',
#  '431_048249_aorta',
#  '938_s0082_liver.nii.g_1',
#  '1537_s0505_aorta.nii.g_1',
#  '1886_s0732_aorta.nii.g_1',
#  '2157_s0924_aorta.nii.g_1',
#  '1146_s0238_aorta.nii.g_1',
#  '1007_s0137_aorta.nii.g_1',
#  '2163_s0928_liver.nii.g_1',
#  '2430_s1128_aorta.nii.g_1',
#  '391_044694_liver',
#  '756_091235_aorta',
#  '1340_s0369_liver.nii.g_1',
#  '513_057428_kidneyright',
#  '738_089268_aorta',
#  '1104_s0211_liver.nii.g_1',
#  '369_042071_kidneyright',
#  '1234_s0303_aorta.nii.g_1',
#  '1868_s0720_aorta.nii.g_1',
#  '1504_s0482_aorta.nii.g_1',
#  '978_s0111_liver.nii.g_1',
#  '133_016881_kidneyright',
#  '1897_s0738_aorta.nii.g_1',
#  '719_086763_liver',
#  '585_069934_kidneyright',
#  '2600_s1252_liver.nii.g_1',
#  '2495_s1173_aorta.nii.g_1',
#  '417_047251_kidneyright',
#  '1307_s0349_liver.nii.g_1',
#  '860_s0029_liver.nii.g_1',
#  '1194_s0265_aorta.nii.g_1',
#  '2448_s1138_aorta.nii.g_1',
#  '2054_s0845_liver.nii.g_1',
#  '527_059710_aorta',
#  '339_037785_kidneyright',
#  '496_056073_liver',
#  '1857_s0714_aorta.nii.g_1',
#  '610_073138_aorta',
#  '2216_s0970_liver.nii.g_1',
#  '1790_s0675_aorta.nii.g_1',
#  '481_054309_liver',
#  '664_078651_kidneyright',
#  '1610_s0556_aorta.nii.g_1',
#  '1735_s0645_aorta.nii.g_1',
#  '1672_s0602_aorta.nii.g_1',
#  '2431_s1129_aorta.nii.g_1',
#  '1229_s0299_aorta.nii.g_1',
#  '1472_s0461_aorta.nii.g_1',
#  '2339_s1052_aorta.nii.g_1',
#  '22_005001_kidneyright',
#  '1799_s0680_liver.nii.g_1',
#  '473_053829_aorta',
#  '1548_s0511_aorta.nii.g_1',
#  '2492_s1171_liver.nii.g_1',
#  '1216_s0289_aorta.nii.g_1',
#  '2284_s1016_aorta.nii.g_1',
#  '1800_s0681_aorta.nii.g_1',
#  '1678_s0605_aorta.nii.g_1',
#  '1903_s0741_aorta.nii.g_1',
#  '1912_s0750_aorta.nii.g_1',
#  '2610_s1258_liver.nii.g_1',
#  '804_097036_aorta',
#  '462_052826_kidneyright',
#  '264_032417_kidneyright',
#  '1687_s0611_aorta.nii.g_1',
#  '1635_s0579_aorta.nii.g_1',
#  '2328_s1044_liver.nii.g_1',
#  '38_007499_liver',
#  '2342_s1058_liver.nii.g_1',
#  '1619_s0564_aorta.nii.g_1',
#  '28_006412_kidneyright',
#  '285_034298_kidneyright',
#  '1330_s0364_liver.nii.g_1',
#  '774_095123_aorta',
#  '630_075415_aorta',
#  '2578_s1240_aorta.nii.g_1',
#  '2086_s0873_aorta.nii.g_1',
#  '1891_s0735_aorta.nii.g_1',
#  '2513_s1187_aorta.nii.g_1',
#  '1149_s0239_liver.nii.g_1',
#  '149_018831_liver',
#  '728_087979_liver',
#  '402_045963_kidneyright',
#  '881_s0045_aorta.nii.g_1',
#  '690_083616_aorta',
#  '866_s0032_liver.nii.g_1',
#  '2151_s0918_aorta.nii.g_1',
#  '655_077260_kidneyright',
#  '1423_s0425_liver.nii.g_1',
#  '2591_s1248_aorta.nii.g_1',
#  '1205_s0279_aorta.nii.g_1',
#  '1416_s0422_aorta.nii.g_1',
#  '2543_s1210_aorta.nii.g_1',
#  '1093_s0201_aorta.nii.g_1',
#  '1630_s0576_aorta.nii.g_1',
#  '1264_s0322_liver.nii.g_1',
#  '420_047449_kidneyright',
#  '476_053966_aorta',
#  '1376_s0391_liver.nii.g_1',
#  '1503_s0481_liver.nii.g_1',
#  '1252_s0314_aorta.nii.g_1',
#  '1758_s0657_aorta.nii.g_1',
#  '1067_s0182_liver.nii.g_1',
#  '59_008717_liver',
#  '1182_s0257_liver.nii.g_1',
#  '900_s0058_liver.nii.g_1',
#  '1572_s0528_liver.nii.g_1',
#  '2552_s1223_aorta.nii.g_1',
#  '291_034619_kidneyright',
#  '1860_s0716_aorta.nii.g_1',
#  '2028_s0829_liver.nii.g_1',
#  '2349_s1062_liver.nii.g_1',
#  '1132_s0230_aorta.nii.g_1',
#  '214_025383_kidneyright',
#  '68_009129_liver',
#  '2446_s1137_aorta.nii.g_1',
#  '1267_s0325_aorta.nii.g_1',
#  '153_019611_aorta',
#  '1422_s0425_aorta.nii.g_1',
#  '581_069901_aorta',
#  '2530_s1201_liver.nii.g_1',
#  '542_061481_aorta',
#  '1716_s0628_aorta.nii.g_1',
#  '1675_s0603_liver.nii.g_1',
#  '247_029523_liver',
#  '1003_s0133_liver.nii.g_1',
#  '875_s0039_liver.nii.g_1',
#  '45_008282_aorta',
#  '1747_s0651_aorta.nii.g_1',
#  '2265_s1002_liver.nii.g_1',
#  '1204_s0277_aorta.nii.g_1',
#  '2150_s0916_liver.nii.g_1',
#  '2415_s1119_aorta.nii.g_1',
#  '1981_s0796_aorta.nii.g_1',
#  '1181_s0257_aorta.nii.g_1',
#  '1034_s0157_liver.nii.g_1',
#  '1357_s0378_aorta.nii.g_1',
#  '588_070383_kidneyright',
#  '2288_s1018_aorta.nii.g_1',
#  '1670_s0600_aorta.nii.g_1',
#  '91_011736_kidneyright',
#  '1718_s0629_aorta.nii.g_1',
#  '2466_s1151_liver.nii.g_1',
#  '2105_s0885_liver.nii.g_1',
#  '434_048645_aorta',
#  '51_008517_aorta',
#  '1980_s0795_liver.nii.g_1',
#  '2287_s1017_liver.nii.g_1',
#  '2199_s0956_liver.nii.g_1',
#  '878_s0042_aorta.nii.g_1',
#  '218_025891_liver',
#  '1612_s0557_aorta.nii.g_1',
#  '1837_s0700_liver.nii.g_1',
#  '116_016386_liver',
#  '284_034298_aorta',
#  '2276_s1009_aorta.nii.g_1',
#  '923_s0073_aorta.nii.g_1',
#  '1931_s0764_aorta.nii.g_1',
#  '786_096001_aorta',
#  '1967_s0788_aorta.nii.g_1',
#  '2252_s0991_liver.nii.g_1',
#  '1767_s0662_aorta.nii.g_1',
#  '1662_s0593_liver.nii.g_1',
#  '1349_s0374_aorta.nii.g_1',
#  '1283_s0334_aorta.nii.g_1',
#  '1027_s0152_aorta.nii.g_1',
#  '1286_s0335_liver.nii.g_1',
#  '1977_s0794_aorta.nii.g_1',
#  '1650_s0586_liver.nii.g_1',
#  '2009_s0813_aorta.nii.g_1',
#  '2227_s0977_aorta.nii.g_1',
#  '1212_s0286_liver.nii.g_1',
#  '2248_s0988_liver.nii.g_1',
#  '827_099815_liver',
#  '2539_s1208_aorta.nii.g_1',
#  '1904_s0743_aorta.nii.g_1',
#  '1581_s0535_aorta.nii.g_1',
#  '717_086763_aorta',
#  '1646_s0584_liver.nii.g_1',
#  '132_016881_aorta',
#  '151_019541_kidneyright',
#  '1766_s0661_liver.nii.g_1',
#  '1870_s0721_aorta.nii.g_1',
#  '2402_s1105_liver.nii.g_1',
#  '2317_s1038_aorta.nii.g_1',
#  '1163_s0246_liver.nii.g_1',
#  '1781_s0670_aorta.nii.g_1',
#  '1564_s0522_aorta.nii.g_1',
#  '2268_s1004_liver.nii.g_1',
#  '1480_s0467_aorta.nii.g_1',
#  '235_027550_liver',
#  '538_060625_liver',
#  '2192_s0951_aorta.nii.g_1',
#  '465_052913_kidneyright',
#  '1864_s0718_aorta.nii.g_1',
#  '12_002737_aorta',
#  '2356_s1069_aorta.nii.g_1',
#  '648_077090_aorta',
#  '1661_s0593_aorta.nii.g_1',
#  '1845_s0705_liver.nii.g_1',
#  '1493_s0473_liver.nii.g_1',
#  '1780_s0669_liver.nii.g_1',
#  '1745_s0650_aorta.nii.g_1',
#  '1338_s0368_liver.nii.g_1',
#  '384_044296_kidneyright',
#  '1809_s0685_liver.nii.g_1',
#  '683_082224_liver',
#  '2451_s1141_aorta.nii.g_1',
#  '1703_s0620_liver.nii.g_1',
#  '1489_s0471_liver.nii.g_1',
#  '700_084728_kidneyright',
#  '1874_s0724_aorta.nii.g_1',
#  '2450_s1140_liver.nii.g_1',
#  '2300_s1026_aorta.nii.g_1',
#  '1883_s0729_liver.nii.g_1',
#  '981_s0114_liver.nii.g_1',
#  '771_094391_aorta',
#  '822_099283_aorta',
#  '1751_s0653_aorta.nii.g_1',
#  '1360_s0380_aorta.nii.g_1',
#  '2382_s1090_liver.nii.g_1',
#  '192_022078_aorta',
#  '1847_s0707_liver.nii.g_1',
#  '1185_s0260_aorta.nii.g_1',
#  '2003_s0810_aorta.nii.g_1',
#  '2576_s1239_aorta.nii.g_1',
#  '2242_s0985_liver.nii.g_1',
#  '204_024073_aorta',
#  '2529_s1201_aorta.nii.g_1',
#  '2234_s0980_liver.nii.g_1',
#  '207_024165_aorta',
#  '825_099815_aorta',
#  '500_057089_aorta',
#  '640_075693_kidneyright',
#  '1046_s0165_liver.nii.g_1',
#  '1770_s0663_liver.nii.g_1',
#  '1848_s0708_aorta.nii.g_1',
#  '2498_s1174_liver.nii.g_1',
#  '1782_s0670_liver.nii.g_1',
#  '1525_s0497_aorta.nii.g_1',
#  '429_047863_kidneyright',
#  '2283_s1015_aorta.nii.g_1',
#  '1231_s0300_aorta.nii.g_1',
#  '563_067664_aorta',
#  '1794_s0677_aorta.nii.g_1',
#  '2405_s1107_aorta.nii.g_1',
#  '389_044694_aorta',
#  '1478_s0465_aorta.nii.g_1',
#  '1705_s0621_liver.nii.g_1',
#  '453_051100_kidneyright',
#  '644_075918_liver',
#  '39_007563_aorta',
#  '1831_s0697_liver.nii.g_1',
#  '1689_s0612_liver.nii.g_1',
#  '1683_s0607_liver.nii.g_1',
#  '1568_s0525_aorta.nii.g_1',
#  '1512_s0486_aorta.nii.g_1',
#  '2140_s0911_liver.nii.g_1',
#  '1791_s0675_liver.nii.g_1',
#  '275_033621_aorta',
#  '669_080184_aorta',
#  '623_073875_liver',
#  '2384_s1094_aorta.nii.g_1',
#  '2008_s0812_liver.nii.g_1',
#  '1817_s0690_liver.nii.g_1',
#  '1813_s0687_liver.nii.g_1',
#  '363_041469_kidneyright',
#  '341_038312_aorta',
#  '1521_s0494_aorta.nii.g_1',
#  '2286_s1017_aorta.nii.g_1',
#  '1246_s0310_aorta.nii.g_1',
#  '1361_s0380_liver.nii.g_1',
#  '1618_s0561_liver.nii.g_1',
#  '2374_s1085_liver.nii.g_1',
#  '1421_s0424_liver.nii.g_1',
#  '1929_s0763_aorta.nii.g_1',
#  '657_078148_aorta',
#  '2329_s1045_aorta.nii.g_1',
#  '1113_s0218_aorta.nii.g_1',
#  '2340_s1052_liver.nii.g_1',
#  '2033_s0832_aorta.nii.g_1',
#  '2206_s0960_aorta.nii.g_1',
#  '1660_s0592_liver.nii.g_1',
#  '886_s0048_liver.nii.g_1',
#  '1368_s0385_aorta.nii.g_1',
#  '1248_s0311_aorta.nii.g_1',
#  '1507_s0483_liver.nii.g_1',
#  '824_099283_liver',
#  '2346_s1061_aorta.nii.g_1',
#  '1454_s0446_liver.nii.g_1',
#  '2630_s1273_liver.nii.g_1',
#  '885_s0048_aorta.nii.g_1',
#  '1600_s0549_liver.nii.g_1',
#  '232_027536_liver',
#  '935_s0080_aorta.nii.g_1',
#  '2477_s1158_liver.nii.g_1',
#  '1965_s0787_aorta.nii.g_1',
#  '754_090513_kidneyright',
#  '1850_s0709_aorta.nii.g_1',
#  '889_s0050_aorta.nii.g_1',
#  '2371_s1084_aorta.nii.g_1',
#  '2184_s0944_aorta.nii.g_1',
#  '427_047727_liver',
#  '1097_s0206_aorta.nii.g_1',
#  '1885_s0731_liver.nii.g_1',
#  '299_035422_aorta',
#  '2589_s1247_aorta.nii.g_1',
#  '747_090087_aorta',
#  '982_s0115_aorta.nii.g_1',
#  '288_034568_kidneyright',
#  '1457_s0450_aorta.nii.g_1',
#  '1276_s0330_aorta.nii.g_1',
#  '2399_s1103_aorta.nii.g_1',
#  '56_008525_liver',
#  '199_022679_kidneyright',
#  '840_s0012_aorta.nii.g_1',
#  '2624_s1270_liver.nii.g_1',
#  '1570_s0527_aorta.nii.g_1',
#  '1648_s0585_liver.nii.g_1',
#  '2304_s1029_aorta.nii.g_1',
#  '98_012980_liver',
#  '1430_s0430_liver.nii.g_1',
#  '2045_s0839_aorta.nii.g_1',
#  '1055_s0171_liver.nii.g_1',
#  '543_061481_kidneyright',
#  '1171_s0250_liver.nii.g_1',
#  '715_086609_kidneyright',
#  '307_035511_liver',
#  '2232_s0979_liver.nii.g_1',
#  '1774_s0665_liver.nii.g_1',
#  '1624_s0571_aorta.nii.g_1',
#  '1963_s0785_aorta.nii.g_1',
#  '1102_s0210_liver.nii.g_1',
#  '1842_s0704_aorta.nii.g_1',
#  '2272_s1007_aorta.nii.g_1',
#  '1978_s0794_liver.nii.g_1',
#  '1277_s0330_liver.nii.g_1',
#  '1492_s0473_aorta.nii.g_1',
#  '1954_s0778_liver.nii.g_1',
#  '2555_s1224_liver.nii.g_1',
#  '8_002056_liver',
#  '1208_s0283_liver.nii.g_1',
#  '1294_s0341_liver.nii.g_1',
#  '2378_s1088_liver.nii.g_1',
#  '845_s0014_liver.nii.g_1',
#  '1506_s0483_aorta.nii.g_1',
#  '2388_s1097_aorta.nii.g_1',
#  '1317_s0356_liver.nii.g_1',
#  '964_s0102_liver.nii.g_1',
#  '372_042241_kidneyright',
#  '925_s0074_aorta.nii.g_1',
#  '779_095778_liver',
#  '2393_s1100_aorta.nii.g_1',
#  '29_006412_liver',
#  '2309_s1033_aorta.nii.g_1',
#  '2449_s1140_aorta.nii.g_1',
#  '2453_s1142_liver.nii.g_1',
#  '819_099061_aorta',
#  '653_077235_liver',
#  '947_s0088_aorta.nii.g_1',
#  '1943_s0771_liver.nii.g_1',
#  '1440_s0438_aorta.nii.g_1',
#  '2330_s1045_liver.nii.g_1',
#  '960_s0096_liver.nii.g_1',
#  '1137_s0232_liver.nii.g_1',
#  '603_072081_kidneyright',
#  '1812_s0687_aorta.nii.g_1',
#  '1342_s0370_liver.nii.g_1',
#  '1145_s0237_liver.nii.g_1',
#  '2396_s1101_liver.nii.g_1',
#  '2436_s1132_aorta.nii.g_1',
#  '2403_s1106_aorta.nii.g_1',
#  '2474_s1157_aorta.nii.g_1',
#  '955_s0092_aorta.nii.g_1',
#  '44_007954_liver',
#  '2000_s0808_aorta.nii.g_1',
#  '745_089747_kidneyright',
#  '1000_s0508_liver.nii.g_1',
#  '395_045104_aorta',
#  '1655_s0590_aorta.nii.g_1',
#  '2023_s0825_aorta.nii.g_1',
#  '2070_s0859_liver.nii.g_1',
#  '914_s0068_liver.nii.g_1',
#  '2593_s1249_aorta.nii.g_1',
#  '1190_s0262_liver.nii.g_1',
#  '2084_s0871_aorta.nii.g_1',
#  '1840_s0703_aorta.nii.g_1',
#  '1896_s0737_liver.nii.g_1',
#  '2560_s1228_aorta.nii.g_1',
#  '1131_s0228_liver.nii.g_1',
#  '2369_s1083_aorta.nii.g_1',
#  '2485_s1164_aorta.nii.g_1',
#  '1535_s0503_aorta.nii.g_1',
#  '2425_s1124_aorta.nii.g_1',
#  '2334_s1048_liver.nii.g_1',
#  '257_030574_aorta',
#  '211_024640_kidneyright',
#  '1465_s0456_liver.nii.g_1',
#  '1351_s0375_aorta.nii.g_1',
#  '478_053966_liver',
#  '277_033621_liver',
#  '762_092807_aorta',
#  '2359_s1070_liver.nii.g_1',
#  '1668_s0598_aorta.nii.g_1',
#  '53_008517_liver',
#  '517_058120_liver',
#  '2351_s1063_liver.nii.g_1',
#  '991_s0123_liver.nii.g_1',
#  '2312_s1035_aorta.nii.g_1',
#  '1901_s0740_aorta.nii.g_1',
#  '1220_s0291_liver.nii.g_1',
#  '202_022953_kidneyright',
#  '470_053737_aorta',
#  '321_036676_kidneyright',
#  '1743_s0649_aorta.nii.g_1',
#  '1455_s0447_aorta.nii.g_1',
#  '127_016793_kidneyright',
#  '1237_s0304_liver.nii.g_1',
#  '245_029523_aorta',
#  '2370_s1083_liver.nii.g_1',
#  '2233_s0980_aorta.nii.g_1',
#  '1425_s0428_aorta.nii.g_1',
#  '1584_s0537_aorta.nii.g_1',
#  '106_014836_kidneyright',
#  '1949_s0775_liver.nii.g_1',
#  '828_s0001_aorta.nii.g_1',
#  '649_077090_kidneyright',
#  '2203_s0958_liver.nii.g_1',
#  '2531_s1203_aorta.nii.g_1',
#  '1728_s0639_aorta.nii.g_1',
#  '41_007563_liver',
#  '910_s0066_liver.nii.g_1',
#  '495_056073_kidneyright',
#  '1622_s0566_aorta.nii.g_1',
#  '1649_s0586_aorta.nii.g_1',
#  '1679_s0605_liver.nii.g_1',
#  '714_086609_aorta',
#  '1337_s0368_aorta.nii.g_1',
#  '1056_s0172_aorta.nii.g_1',
#  '1116_s0219_liver.nii.g_1',
#  '1764_s0660_aorta.nii.g_1',
#  '2437_s1132_liver.nii.g_1',
#  '574_068738_liver',
#  '2016_s0820_aorta.nii.g_1',
#  '2381_s1090_aorta.nii.g_1',
#  '1732_s0643_aorta.nii.g_1',
#  '790_096605_kidneyright',
#  '185_021375_liver',
#  '1110_s0215_liver.nii.g_1',
#  '530_059817_aorta',
#  '1792_s0676_aorta.nii.g_1',
#  '1559_s0519_aorta.nii.g_1',
#  '2103_s0884_liver.nii.g_1',
#  '446_049696_aorta',
#  '2243_s0986_aorta.nii.g_1',
#  '1795_s0677_liver.nii.g_1',
#  '1893_s0736_aorta.nii.g_1',
#  '422_047501_aorta',
#  '115_016386_kidneyright',
#  '2180_s0940_aorta.nii.g_1',
#  '850_s0019_aorta.nii.g_1',
#  '1631_s0577_aorta.nii.g_1',
#  '2302_s1028_aorta.nii.g_1',
#  '1859_s0715_aorta.nii.g_1',
#  '166_020555_kidneyright',
#  '1637_s0580_aorta.nii.g_1',
#  '261_031618_kidneyright',
#  '392_044814_aorta',
#  '1898_s0738_liver.nii.g_1',
#  '2219_s0972_liver.nii.g_1',
#  '2020_s0822_liver.nii.g_1',
#  '1187_s0261_aorta.nii.g_1',
#  '345_038550_kidneyright',
#  '691_083616_kidneyright',
#  '1515_s0487_liver.nii.g_1',
#  '2015_s0819_aorta.nii.g_1',
#  '1909_s0747_liver.nii.g_1',
#  '1473_s0461_liver.nii.g_1',
#  '485_055211_aorta',
#  '1166_s0248_aorta.nii.g_1',
#  '1846_s0707_aorta.nii.g_1',
#  '2271_s1006_liver.nii.g_1',
#  '710_085763_liver',
#  '995_s0128_liver.nii.g_1',
#  '1274_s0329_aorta.nii.g_1',
#  '1993_s0804_liver.nii.g_1',
#  '2200_s0957_aorta.nii.g_1',
#  '335_037622_aorta',
#  '2488_s1165_liver.nii.g_1',
#  '52_008517_kidneyright',
#  '138_017214_aorta',
#  '1721_s0632_liver.nii.g_1',
#  '2123_s0898_liver.nii.g_1',
#  '1230_s0299_liver.nii.g_1',
#  '1300_s0344_liver.nii.g_1',
#  '2182_s0941_aorta.nii.g_1',
#  '2_000442_liver',
#  '2181_s0940_liver.nii.g_1',
#  '2133_s0907_liver.nii.g_1',
#  '23_005001_liver',
#  '2480_s1161_aorta.nii.g_1',
#  '2590_s1247_liver.nii.g_1',
#  '673_080221_kidneyright',
#  '216_025891_aorta',
#  '1843_s0704_liver.nii.g_1',
#  '584_069934_aorta',
#  '2152_s0918_liver.nii.g_1',
#  '248_029572_aorta',
#  '1530_s0500_aorta.nii.g_1',
#  '1024_s0150_liver.nii.g_1',
#  '184_021375_kidneyright',
#  '460_051928_liver',
#  '1339_s0369_aorta.nii.g_1',
#  '628_075049_kidneyright',
#  '2314_s1036_aorta.nii.g_1',
#  '2571_s1236_liver.nii.g_1',
#  '1048_s0166_liver.nii.g_1',
#  '613_073351_kidneyright',
#  '1061_s0178_aorta.nii.g_1',
#  '503_057155_aorta',
#  '879_s0042_liver.nii.g_1',
#  '1039_s0161_aorta.nii.g_1',
#  '1514_s0487_aorta.nii.g_1',
#  '1179_s0256_aorta.nii.g_1',
#  '1311_s0353_liver.nii.g_1',
#  '371_042241_aorta',
#  '570_068179_kidneyright',
#  '2102_s0884_aorta.nii.g_1',
#  '55_008525_kidneyright',
#  '1968_s0788_liver.nii.g_1',
#  '801_097021_aorta',
#  '1704_s0621_aorta.nii.g_1',
#  '1982_s0796_liver.nii.g_1',
#  '231_027536_aorta',
#  '652_077235_kidneyright',
#  '282_033663_kidneyright',
#  '2303_s1028_liver.nii.g_1',
#  '1490_s0472_aorta.nii.g_1',
#  '399_045776_kidneyright',
#  '70_009310_kidneyright',
#  '1062_s0178_liver.nii.g_1',
#  '1135_s0231_liver.nii.g_1',
#  '209_024165_liver',
#  '1343_s0371_aorta.nii.g_1',
#  '2400_s1103_liver.nii.g_1',
#  '946_s0086_liver.nii.g_1',
#  '267_032502_kidneyright',
#  '1802_s0682_aorta.nii.g_1',
#  '108_015731_aorta',
#  '1196_s0266_aorta.nii.g_1',
#  '1427_s0429_aorta.nii.g_1',
#  '2617_s1264_liver.nii.g_1',
#  '350_040288_aorta',
#  '1256_s0316_aorta.nii.g_1',
#  '1663_s0594_aorta.nii.g_1',
#  '2144_s0913_liver.nii.g_1',
#  '217_025891_kidneyright',
#  '1232_s0300_liver.nii.g_1',
#  '1009_s0138_aorta.nii.g_1',
#  '27_006412_aorta',
#  '1001_s0509_aorta.nii.g_1',
#  '436_048645_liver',
#  '2245_s0987_aorta.nii.g_1',
#  '2217_s0971_aorta.nii.g_1',
#  '617_073465_liver',
#  '121_016657_kidneyright',
#  '1284_s0334_liver.nii.g_1',
#  '2075_s0863_liver.nii.g_1',
#  '1922_s0756_aorta.nii.g_1',
#  '1753_s0654_liver.nii.g_1',
#  '2412_s1113_aorta.nii.g_1',
#  '2007_s0812_aorta.nii.g_1',
#  '1578_s0531_liver.nii.g_1',
#  '2336_s1049_liver.nii.g_1',
#  '2469_s1153_aorta.nii.g_1',
#  '1424_s0426_aorta.nii.g_1',
#  '1012_s0139_liver.nii.g_1',
#  '2554_s1224_aorta.nii.g_1',
#  '2081_s0868_aorta.nii.g_1',
#  '357_040984_kidneyright',
#  '2544_s1210_liver.nii.g_1',
#  '1952_s0777_liver.nii.g_1',
#  '1925_s0760_aorta.nii.g_1',
#  '557_066154_aorta',
#  '46_008282_kidneyright',
#  '2145_s0914_aorta.nii.g_1',
#  '2186_s0945_liver.nii.g_1',
#  '1243_s0307_liver.nii.g_1',
#  '1242_s0307_aorta.nii.g_1',
#  '778_095778_kidneyright',
#  '2360_s1073_aorta.nii.g_1',
#  '2548_s1216_liver.nii.g_1',
#  '2002_s0809_aorta.nii.g_1',
#  '524_059426_aorta',
#  '1089_s0197_aorta.nii.g_1',
#  '512_057428_aorta',
#  '351_040288_kidneyright',
#  '2344_s1060_aorta.nii.g_1',
#  '2168_s0933_aorta.nii.g_1',
#  '1905_s0743_liver.nii.g_1',
#  '1410_s0416_liver.nii.g_1',
#  '1411_s0419_aorta.nii.g_1',
#  '490_055543_liver',
#  '1586_s0541_liver.nii.g_1',
#  '1366_s0383_aorta.nii.g_1',
#  '484_054461_liver',
#  '789_096605_aorta',
#  '1617_s0561_aorta.nii.g_1',
#  '1541_s0507_liver.nii.g_1',
#  '711_086237_aorta',
#  '1375_s0391_aorta.nii.g_1',
#  '654_077260_aorta',
#  '1566_s0523_aorta.nii.g_1',
#  '706_085489_kidneyright',
#  '1206_s0281_aorta.nii.g_1',
#  '2365_s1079_aorta.nii.g_1',
#  '1388_s0401_aorta.nii.g_1',
#  '1627_s0573_liver.nii.g_1',
#  '1029_s0153_liver.nii.g_1',
#  '809_097446_liver',
#  '2354_s1067_aorta.nii.g_1',
#  '695_083783_liver',
#  '609_072389_liver',
#  '928_s0076_aorta.nii.g_1',
#  '1270_s0327_aorta.nii.g_1',
#  '2585_s1244_aorta.nii.g_1',
#  '1394_s0405_aorta.nii.g_1',
#  '689_083154_liver',
#  '338_037785_aorta',
#  '1018_s0145_liver.nii.g_1',
#  '2376_s1086_liver.nii.g_1',
#  '1014_s0141_liver.nii.g_1',
#  '1209_s0285_aorta.nii.g_1',
#  '2401_s1105_aorta.nii.g_1',
#  '1426_s0428_liver.nii.g_1',
#  '1380_s0393_liver.nii.g_1',
#  '1017_s0145_aorta.nii.g_1',
#  '760_091344_kidneyright',
#  '980_s0114_aorta.nii.g_1',
#  '1332_s0365_liver.nii.g_1',
#  '1223_s0293_liver.nii.g_1',
#  '2189_s0949_aorta.nii.g_1',
#  '682_082224_kidneyright',
#  '1074_s0188_liver.nii.g_1',
#  '698_084161_liver',
#  '6_002056_aorta',
#  '1602_s0550_liver.nii.g_1',
#  '2570_s1236_aorta.nii.g_1',
#  '1399_s0407_liver.nii.g_1',
#  '1227_s0298_aorta.nii.g_1',
#  '188_021910_liver',
#  '48_008512_aorta',
#  '2058_s0847_liver.nii.g_1',
#  '421_047449_liver',
#  '2455_s1143_liver.nii.g_1',
#  '16_003164_kidneyright',
#  '1785_s0672_aorta.nii.g_1',
#  '1531_s0500_liver.nii.g_1',
#  '330_037413_kidneyright',
#  '472_053737_liver',
#  '1711_s0625_aorta.nii.g_1',
#  '2532_s1203_liver.nii.g_1',
#  '580_069186_liver',
#  '2534_s1205_liver.nii.g_1',
#  '270_033251_kidneyright',
#  '1068_s0183_aorta.nii.g_1',
#  '2315_s1037_aorta.nii.g_1',
#  '2361_s1073_liver.nii.g_1',
#  '4_001313_kidneyright',
#  '20_004329_liver',
#  '896_s0054_liver.nii.g_1',
#  '830_s0004_aorta.nii.g_1',
#  '2574_s1238_aorta.nii.g_1',
#  '961_s0098_aorta.nii.g_1',
#  '2130_s0904_aorta.nii.g_1',
#  '1552_s0515_aorta.nii.g_1',
#  '634_075418_kidneyright',
#  '1621_s0565_liver.nii.g_1',
#  '2208_s0961_liver.nii.g_1',
#  '386_044688_aorta',
#  '1099_s0209_aorta.nii.g_1',
#  '2171_s0934_liver.nii.g_1',
#  '104_013514_liver',
#  '2006_s0811_liver.nii.g_1',
#  '2158_s0924_liver.nii.g_1',
#  '932_s0078_aorta.nii.g_1',
#  '1245_s0308_liver.nii.g_1',
#  '856_s0024_liver.nii.g_1',
#  '477_053966_kidneyright',
#  '474_053829_kidneyright',
#  '1699_s0618_liver.nii.g_1',
#  '799_096920_kidneyright',
#  '1807_s0684_liver.nii.g_1',
#  '897_s0057_aorta.nii.g_1',
#  '1119_s0221_aorta.nii.g_1',
#  '2270_s1006_aorta.nii.g_1',
#  '2581_s1241_liver.nii.g_1',
#  '1240_s0306_aorta.nii.g_1',
#  '2417_s1120_aorta.nii.g_1',
#  '1736_s0645_liver.nii.g_1',
#  '1091_s0199_aorta.nii.g_1',
#  '665_078651_liver',
#  '1164_s0247_aorta.nii.g_1',
#  '415_046988_liver',
#  '2390_s1098_aorta.nii.g_1',
#  '1991_s0802_liver.nii.g_1',
#  '243_029055_kidneyright',
#  '797_096761_liver',
#  '2343_s1059_aorta.nii.g_1',
#  '1579_s0532_aorta.nii.g_1',
#  '494_056073_aorta',
#  '1690_s0613_aorta.nii.g_1',
#  '403_045963_liver',
#  '1665_s0595_aorta.nii.g_1',
#  '904_s0062_aorta.nii.g_1',
#  '906_s0063_aorta.nii.g_1',
#  '181_021240_kidneyright',
#  '2156_s0923_liver.nii.g_1',
#  '123_016783_aorta',
#  '2561_s1228_liver.nii.g_1',
#  '1505_s0482_liver.nii.g_1',
#  '2470_s1153_liver.nii.g_1',
#  '752_090464_liver',
#  '2014_s0816_liver.nii.g_1',
#  '1038_s0160_liver.nii.g_1',
#  '2514_s1187_liver.nii.g_1',
#  '1301_s0345_aorta.nii.g_1',
#  '1821_s0692_liver.nii.g_1',
#  '10_002459_kidneyright',
#  '1917_s0752_liver.nii.g_1',
#  '30_006919_aorta',
#  '833_s0006_liver.nii.g_1',
#  '2316_s1037_liver.nii.g_1',
#  '2012_s0815_aorta.nii.g_1',
#  '1861_s0716_liver.nii.g_1',
#  '639_075693_aorta',
#  '2119_s0896_liver.nii.g_1',
#  '300_035422_kidneyright',
#  '2159_s0925_aorta.nii.g_1',
#  '593_070937_aorta',
#  '1476_s0463_aorta.nii.g_1',
#  '2044_s0838_liver.nii.g_1',
#  '564_067664_kidneyright',
#  '651_077235_aorta',
#  '1540_s0507_aorta.nii.g_1',
#  '1609_s0555_liver.nii.g_1',
#  '1086_s0194_liver.nii.g_1',
#  '1746_s0650_liver.nii.g_1',
#  '1320_s0358_aorta.nii.g_1',
#  '1456_s0447_liver.nii.g_1',
#  '24_005703_aorta',
#  '942_s0084_liver.nii.g_1',
#  '1200_s0271_aorta.nii.g_1',
#  '1328_s0363_liver.nii.g_1',
#  '1412_s0420_aorta.nii.g_1',
#  '196_022538_kidneyright',
#  '1436_s0436_aorta.nii.g_1',
#  '676_080269_kidneyright',
#  '927_s0075_liver.nii.g_1',
#  '750_090464_aorta',
#  '1370_s0386_liver.nii.g_1',
#  '616_073465_kidneyright',
#  '306_035511_kidneyright',
#  '81_010445_aorta',
#  '172_020636_kidneyright',
#  '566_067929_aorta',
#  '1341_s0370_aorta.nii.g_1',
#  '931_s0077_liver.nii.g_1',
#  '1911_s0749_liver.nii.g_1',
#  '2613_s1261_aorta.nii.g_1',
#  '1748_s0651_liver.nii.g_1',
#  '1334_s0366_liver.nii.g_1',
#  '622_073875_kidneyright',
#  '1167_s0248_liver.nii.g_1',
#  '1996_s0806_aorta.nii.g_1',
#  '861_s0030_aorta.nii.g_1',
#  '586_069934_liver',
#  '2223_s0975_aorta.nii.g_1',
#  '1680_s0606_aorta.nii.g_1',
#  '2483_s1162_liver.nii.g_1',
#  '1391_s0402_liver.nii.g_1',
#  '903_s0061_aorta.nii.g_1',
#  '1811_s0686_liver.nii.g_1',
#  '1469_s0458_liver.nii.g_1',
#  '699_084728_aorta',
#  '681_082224_aorta',
#  '1077_s0190_aorta.nii.g_1',
#  '2307_s1031_liver.nii.g_1',
#  '598_071743_liver',
#  '1676_s0604_aorta.nii.g_1',
#  '2626_s1271_liver.nii.g_1',
#  '1295_s0342_aorta.nii.g_1',
#  '1101_s0210_aorta.nii.g_1',
#  '304_035445_liver',
#  '1297_s0343_aorta.nii.g_1',
#  '1536_s0504_aorta.nii.g_1',
#  '2188_s0946_liver.nii.g_1',
#  '1326_s0362_liver.nii.g_1',
#  '2305_s1029_liver.nii.g_1',
#  '1856_s0712_aorta.nii.g_1',
#  '418_047251_liver',
#  '1296_s0342_liver.nii.g_1',
#  '489_055543_kidneyright',
#  '2207_s0961_aorta.nii.g_1',
#  '798_096920_aorta',
#  '1876_s0726_aorta.nii.g_1',
#  '1019_s0146_aorta.nii.g_1',
#  '751_090464_kidneyright',
#  '1797_s0679_liver.nii.g_1',
#  '775_095123_kidneyright',
#  '2364_s1077_liver.nii.g_1',
#  '1129_s0227_liver.nii.g_1',
#  '347_039942_aorta',
#  '859_s0029_aorta.nii.g_1',
#  '15_003164_aorta',
#  '1433_s0433_aorta.nii.g_1',
#  '1292_s0339_liver.nii.g_1',
#  '545_062131_aorta',
#  '796_096761_kidneyright',
#  '803_097021_liver',
#  '2537_s1207_aorta.nii.g_1',
#  '1371_s0389_aorta.nii.g_1',
#  '2517_s1190_aorta.nii.g_1',
#  '2078_s0865_aorta.nii.g_1',
#  '823_099283_kidneyright',
#  '1990_s0802_aorta.nii.g_1',
#  '549_062219_kidneyright',
#  '2162_s0928_aorta.nii.g_1',
#  '633_075418_aorta',
#  '546_062131_kidneyright',
#  '1260_s0320_liver.nii.g_1',
#  '447_049696_kidneyright',
#  '772_094391_kidneyright',
#  '229_027527_kidneyright',
#  '2348_s1062_aorta.nii.g_1',
#  '1477_s0463_liver.nii.g_1',
#  '1591_s0544_aorta.nii.g_1',
#  '1849_s0708_liver.nii.g_1',
#  '2345_s1060_liver.nii.g_1',
#  '1894_s0736_liver.nii.g_1',
#  '951_s0090_aorta.nii.g_1',
#  '1442_s0439_aorta.nii.g_1',
#  '548_062219_aorta',
#  '1117_s0220_aorta.nii.g_1',
#  '1686_s0610_aorta.nii.g_1',
#  '2507_s1182_aorta.nii.g_1',
#  '482_054461_aorta',
#  '398_045776_aorta',
#  '497_056839_aorta',
#  '271_033251_liver',
#  '137_017081_liver',
#  '795_096761_aorta',
#  '2579_s1240_liver.nii.g_1',
#  '851_s0019_liver.nii.g_1',
#  '857_s0028_aorta.nii.g_1',
#  '425_047727_aorta',
#  '2493_s1172_aorta.nii.g_1',
#  '1825_s0694_liver.nii.g_1',
#  '1532_s0501_aorta.nii.g_1',
#  '2146_s0914_liver.nii.g_1',
#  '413_046988_aorta',
#  '2569_s1235_liver.nii.g_1',
#  '621_073875_aorta',
#  '841_s0012_liver.nii.g_1',
#  '438_048750_kidneyright',
#  '1333_s0366_aorta.nii.g_1',
#  '2092_s0878_aorta.nii.g_1',
#  '1997_s0806_liver.nii.g_1',
#  '1491_s0472_liver.nii.g_1',
#  '1604_s0551_liver.nii.g_1',
#  '1761_s0658_liver.nii.g_1',
#  '837_s0010_liver.nii.g_1',
#  '2224_s0975_liver.nii.g_1',
#  '1611_s0556_liver.nii.g_1',
#  '334_037591_liver',
#  '326_036915_aorta',
#  '1221_s0292_aorta.nii.g_1',
#  '802_097021_kidneyright',
#  '2135_s0908_liver.nii.g_1',
#  '1715_s0627_aorta.nii.g_1',
#  '432_048249_kidneyright',
#  '882_s0045_liver.nii.g_1',
#  '2325_s1042_liver.nii.g_1',
#  '2586_s1244_liver.nii.g_1',
#  '1733_s0644_aorta.nii.g_1',
#  '759_091344_aorta',
#  '144_017917_aorta',
#  '2550_s1221_aorta.nii.g_1',
#  '2386_s1096_aorta.nii.g_1',
#  '2489_s1167_aorta.nii.g_1',
#  '140_017214_liver',
#  '547_062131_liver',
#  '2274_s1008_aorta.nii.g_1',
#  '696_084161_aorta',
#  '1258_s0319_liver.nii.g_1',
#  '1517_s0488_liver.nii.g_1',
#  '342_038312_kidneyright',
#  '2414_s1115_aorta.nii.g_1',
#  '1218_s0290_liver.nii.g_1',
#  '19_004329_kidneyright',
#  '729_088669_aorta',
#  '1058_s0174_liver.nii.g_1',
#  '376_042966_liver',
#  '169_020586_kidneyright',
#  '2087_s0874_aorta.nii.g_1',
#  '455_051720_aorta',
#  '1772_s0664_liver.nii.g_1',
#  '1369_s0386_aorta.nii.g_1',
#  '1201_s0271_liver.nii.g_1',
#  '1023_s0150_aorta.nii.g_1',
#  '2031_s0831_aorta.nii.g_1',
#  '1719_s0629_liver.nii.g_1',
#  '541_060752_liver',
#  '2117_s0895_liver.nii.g_1',
#  '1633_s0578_aorta.nii.g_1',
#  '2428_s1127_aorta.nii.g_1',
#  '2604_s1255_liver.nii.g_1',
#  '66_009129_aorta',
#  '1805_s0683_liver.nii.g_1',
#  '355_040971_liver',
#  '1398_s0407_aorta.nii.g_1',
#  '2093_s0878_liver.nii.g_1',
#  '1156_s0243_aorta.nii.g_1',
#  '1685_s0608_liver.nii.g_1',
#  '721_087631_kidneyright',
#  '387_044688_kidneyright',
#  '191_022056_liver',
#  '2285_s1016_liver.nii.g_1',
#  '320_036676_aorta',
#  '2178_s0939_aorta.nii.g_1',
#  '450_050630_kidneyright',
#  '842_s0013_aorta.nii.g_1',
#  '290_034619_aorta',
#  '1986_s0798_liver.nii.g_1',
#  '2121_s0897_liver.nii.g_1',
#  '1468_s0458_aorta.nii.g_1',
#  '1042_s0162_liver.nii.g_1',
#  '1290_s0338_liver.nii.g_1',
#  '311_036034_aorta',
#  '2221_s0973_liver.nii.g_1',
#  '1498_s0477_liver.nii.g_1',
#  '1934_s0765_liver.nii.g_1',
#  '2528_s1199_liver.nii.g_1',
#  '2372_s1084_liver.nii.g_1',
#  '1142_s0236_aorta.nii.g_1',
#  '1725_s0636_liver.nii.g_1',
#  '985_s0117_liver.nii.g_1',
#  '907_s0065_aorta.nii.g_1',
#  '1545_s0509_liver.nii.g_1',
#  '1453_s0446_aorta.nii.g_1',
#  '1336_s0367_liver.nii.g_1',
#  '1776_s0667_liver.nii.g_1',
#  '2627_s1272_aorta.nii.g_1',
#  '200_022679_liver',
#  '625_074496_kidneyright',
#  '1863_s0717_liver.nii.g_1',
#  '131_016838_liver',
#  '2101_s0883_liver.nii.g_1',
#  '2310_s1033_liver.nii.g_1',
#  '1582_s0536_aorta.nii.g_1',
#  '1329_s0364_aorta.nii.g_1',
#  '1889_s0733_liver.nii.g_1',
#  '533_060478_aorta',
#  '1956_s0780_liver.nii.g_1',
#  '1546_s0510_aorta.nii.g_1',
#  '167_020555_liver',
#  '702_085229_aorta',
#  '1918_s0753_aorta.nii.g_1',
#  '1713_s0626_aorta.nii.g_1',
#  '2601_s1254_aorta.nii.g_1',
#  '1775_s0667_aorta.nii.g_1',
#  '1692_s0615_aorta.nii.g_1',
#  '2443_s1135_liver.nii.g_1',
#  '1708_s0623_liver.nii.g_1',
#  '1106_s0212_liver.nii.g_1',
#  '1006_s0136_aorta.nii.g_1',
#  '1851_s0709_liver.nii.g_1',
#  '186_021910_aorta',
#  '1467_s0457_liver.nii.g_1',
#  '987_s0119_liver.nii.g_1',
#  '276_033621_kidneyright',
#  '43_007954_kidneyright',
#  ...]

# %%
len(organs), len(available_latents)
# Out:
# (2500, 1381)

# %%
# id setting was bugged, had to do it again
organs['id']  = organs["new_index"].astype(str) + '_' + organs['Name'].apply(lambda x: x.split('.stl')[0])

# %%
organs
# Out:
#       new_index  original_index                     Name     Category  \
# 0          1061           45713  s0178_aorta.nii.g_1.stl        aorta
# 1           127            8720   016793_kidneyright.stl  kidneyright
# 2           714           30529         086609_aorta.stl        aorta
# 3          2285           92354  s1016_liver.nii.g_1.stl        liver
# 4          1687           68838  s0611_aorta.nii.g_1.stl        aorta
# ...         ...             ...                      ...          ...
# 2495       2385           96504  s1094_liver.nii.g_1.stl        liver
# 2496       1088           46642  s0196_liver.nii.g_1.stl        liver
# 2497        426           19830   047727_kidneyright.stl  kidneyright
# 2498       2608          105140  s1257_liver.nii.g_1.stl        liver
# 2499        972           42561  s0108_aorta.nii.g_1.stl        aorta
#
#                                                     URL SubCategory  \
# 0     https://uni-duisburg-essen.sciebo.de/s/HeShw1G...       aorta
# 1     https://uni-duisburg-essen.sciebo.de/s/HeShw1G...      kidney
# 2     https://uni-duisburg-essen.sciebo.de/s/HeShw1G...       aorta
# 3     https://uni-duisburg-essen.sciebo.de/s/HeShw1G...       liver
# 4     https://uni-duisburg-essen.sciebo.de/s/HeShw1G...       aorta
# ...                                                 ...         ...
# 2495  https://uni-duisburg-essen.sciebo.de/s/HeShw1G...       liver
# 2496  https://uni-duisburg-essen.sciebo.de/s/HeShw1G...       liver
# 2497  https://uni-duisburg-essen.sciebo.de/s/HeShw1G...      kidney
# 2498  https://uni-duisburg-essen.sciebo.de/s/HeShw1G...       liver
# 2499  https://uni-duisburg-essen.sciebo.de/s/HeShw1G...       aorta
#
#                             id
# 0     1061_s0178_aorta.nii.g_1
# 1       127_016793_kidneyright
# 2             714_086609_aorta
# 3     2285_s1016_liver.nii.g_1
# 4     1687_s0611_aorta.nii.g_1
# ...                        ...
# 2495  2385_s1094_liver.nii.g_1
# 2496  1088_s0196_liver.nii.g_1
# 2497    426_047727_kidneyright
# 2498  2608_s1257_liver.nii.g_1
# 2499   972_s0108_aorta.nii.g_1
#
# [2500 rows x 7 columns]

# %%
organs = organs[organs["id"].isin(available_latents)]
len(organs), len(available_latents)
# Out:
# (1376, 1381)

# %%
organs_train, organs_test = train_test_split(
    organs,
    test_size=TEST_SIZE,
    stratify=organs["Category"]
)
organs_test, organs_val = train_test_split(
    organs_test,
    test_size=VAL_SIZE,
    stratify=organs_test["Category"]
)

organs_train.shape, organs_test.shape, organs_val.shape
# Out:
# ((1100, 7), (138, 7), (138, 7))

# %%
organs_train["Category"].value_counts()
# Out:
# Category
# aorta          540
# liver          437
# kidneyright    123
# Name: count, dtype: int64

# %%
organs_test["Category"].value_counts()
# Out:
# Category
# aorta          68
# liver          55
# kidneyright    15
# Name: count, dtype: int64

# %%
organs_val["Category"].value_counts()
# Out:
# Category
# aorta          68
# liver          54
# kidneyright    16
# Name: count, dtype: int64

# %%
lista_ids_train = list(organs_train.id.values)
lista_ids_test = list(organs_test.id.values)
lista_ids_val = list(organs_val.id.values)

# %%
with open('train_organs.pickle', 'wb') as file:
    pickle.dump(lista_ids_train, file)

with open('test_organs.pickle', 'wb') as file:
    pickle.dump(lista_ids_test, file)

with open('val_organs.pickle', 'wb') as file:
    pickle.dump(lista_ids_val, file)

# %%
csv_organs = organs[['id', 'Category']]

csv_organs.to_csv('organs_selected_complete.csv', index = False, header=False)
